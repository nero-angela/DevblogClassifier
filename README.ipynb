# %% [markdown]
# # # How To Run

# %%
from main import *

# %%
predict('손흥민 시즌 13호골! epl 25라운드 토트넘 vs 맨체스터시티') # 2020년 02월 03일에 등록된 글 제목

# %%
predict('필리핀 세부 시티의 맛집! 하우스 오브 레촌, cebu city, House of Lechon') # 2020년 02월 03일에 등록된 글 제목
# Out:
# (False, 0.012)

# %%
predict('자바 String, StringBuilder 그리고 StringBuffer 차이 비교') # 2020년 02월 03일에 등록된 글 제목
# Out:
# (True, 0.999)

# %%
predict('docker기반 데이터 시각화툴 Superset 설치하기 (리눅스)') # 2020년 02월 03일에 등록된 글 제목
# Out:
# (True, 0.975)

# %% [markdown]
# ---
# # # Data

# %%
# train data
data = getTrainData()

# %%
# data 구조
data.sample(2)
# Out:
#        index  label                       _id  \
# 21364   2061      1  5cffe1002b1456000486dacb
# 24608    405      1  5d8db4f60b1dbd0004f4ec5c
#
#                                                title  \
# 21364  kubernetes operator sdk를 이용한 helm operator 개발
# 24608   react class 와 react hooks 를 활용한 함수형 방식 구현 비교
#
#                                              description              tags  \
# 21364  operator sdk user guide에 소개된 nginx operator 예제...  nginx kubernetes
# 24608  dataadslot react 를 class 방식으로 구현하는 방법이 있고 hook...               NaN
#
#                                                     link  \
# 21364  https://ssup2.github.io/programming/kubernetes...
# 24608                 https://aspdotnet.tistory.com/2283
#
#                                                     text  \
# 21364  nginx kubernetes kubernetes operator sdk를 이용한 ...
# 24608   react class 와 react hooks 를 활용한 함수형 방식 구현 비교 ...
#
#                                                   vector
# ...

# %%
# data analysis
getDataAnalysis()
# Out:
# > 데이터 수량 조사
# 전체 데이터 수: 34620개
# 라벨링된 데이터 수: 10382개
# class -1 : 24238개
# class 1 : 7634개
# class 0 : 2748개
#
# > 문장 길이 분석
# 문장 길이 최대 값: 358
# 문장 길이 최소 값: 3
# 문장 길이 평균 값: 145.02
# 문장 길이 표준편차: 60.59
# 문장 길이 중간 값: 132.0
# 문장 길이 제 1 사분위: 108.0
# 문장 길이 제 3 사분위: 203.0

# %% [markdown]
# # # Word Vector Model

# %%
# word to vector
wv.vectorization(wv_model, '파이썬')
# Out:
# array([-1.48815408e-01, -1.17857963e-01, -8.72064084e-02,  4.93978858e-02,
#         1.41432300e-01,  9.49753374e-02, -6.93019107e-02,  4.18673828e-03,
#         4.86976393e-02,  1.31665289e-01, -2.02226058e-01, -8.66764039e-03,
#        -3.45623493e-02,  1.50093883e-01,  8.98581743e-03,  5.87398894e-02,
#         4.53059897e-02, -1.22770073e-03,  1.71326362e-02,  7.44685829e-02,
#        -2.12160572e-02,  1.21598467e-02, -9.41937342e-02,  4.67983186e-02,
#        -3.94061618e-02,  4.12501395e-01, -1.31122023e-03, -7.47695118e-02,
#        -9.48062688e-02,  5.56808524e-03,  2.16821611e-01,  1.62936836e-01,
#        -3.33731323e-02, -4.80934307e-02,  1.00398630e-01, -1.33311562e-02,
#        -1.12874627e-01,  3.91419381e-02, -1.01466537e-01, -1.82012357e-02,
#        -1.20168112e-01, -8.55559409e-02, -5.27738035e-02, -3.33135948e-02,
#        -2.87191439e-02,  3.46537381e-02,  3.86811346e-02,  2.23775730e-02,
# ...

# %%
# 단어 임베딩이 되면 유사 단어 조회도 가능
getSimilarWords('파이썬')
# Out:
# [('Python', 0.565061628818512),
#  ('자이썬', 0.5624369382858276),
#  ('레일스', 0.5598082542419434),
#  ('파이썬을', 0.5595801472663879),
#  ('언어용', 0.5288202166557312)]

# %% [markdown]
# # # Train
# - 성능
#  - loss : 0.2777881861213504
#  - accuracy : 0.8832798600196838
#  - f1_score : 0.8475756645202637
#  - precision : 0.7391010522842407
#  - recall : 1.0

# %%
train()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 100)               30100
# _________________________________________________________________
# dense_1 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 162
# ...
# Total params: 38,342
# Trainable params: 38,342
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6259 samples, validate on 696 samples
# Epoch 1/10
# 5800/6259 [==========================>...] - ETA: 0s - loss: 0.4984 - acc: 0.7471 - f1_m: 0.8451 - precision_m: 0.7331 - recall_m: 1.0000
# Epoch 00001: val_acc improved from -inf to 0.84914, saving model to ./model/200215
# ...
